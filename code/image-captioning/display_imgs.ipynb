# %%
from IPython.display import Image
from IPython.core.display import HTML 

PATH = '/home/gusviloca@GU.GU.SE/aics-vizwiz/vizwiz/'
Image(filename = PATH + 'VizWiz_train_00008111.jpg',
      width=300, height=300)
